# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Credit_Card.csv')
df1 = pd.read_csv('Credit_Record.csv')

# %%
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
df1.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %%
data = pd.merge(df,df1, on='ID')

# %%
data.head(6)
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008804           M            Y               Y             0
# 2  5008804           M            Y               Y             0
# 3  5008804           M            Y               Y             0
# 4  5008804           M            Y               Y             0
# 5  5008804           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          427500.0          Working    Higher education     Civil marriage
# 1          427500.0          Working    Higher education     Civil marriage
# 2          427500.0          Working    Higher education     Civil marriage
# 3          427500.0          Working    Higher education     Civil marriage
# 4          427500.0          Working    Higher education     Civil marriage
# ...

# %%
data.columns
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS', 'MONTHS_BALANCE',
#        'STATUS'],
#       dtype='object')

# %%
data = data.rename(columns={'ID':'Id','CODE_GENDER':'Gender','FLAG_OWN_CAR':'Own_Car','FLAG_OWN_REALTY':'Property_Type','CNT_CHILDREN':'Children',
                     'AMT_INCOME_TOTAL':'Income', 'NAME_INCOME_TYPE':'Income_Type','NAME_EDUCATION_TYPE':'Education',
       'NAME_FAMILY_STATUS':'Marital_Status', 'NAME_HOUSING_TYPE':'House_Type', 'DAYS_BIRTH':'Age',
       'DAYS_EMPLOYED':'Experience', 'FLAG_MOBIL':'Mobile', 'FLAG_WORK_PHONE':'Office_Phone', 'FLAG_PHONE':'Phone',
       'FLAG_EMAIL':'Email', 'OCCUPATION_TYPE':'Occupation_Type', 'CNT_FAM_MEMBERS':'Family_Members', 
                     'MONTHS_BALANCE':'Month_Balance','STATUS':'Status'})

# %%
data.head()
# Out:
#         Id Gender Own_Car Property_Type  Children    Income Income_Type  \
# 0  5008804      M       Y             Y         0  427500.0     Working
# 1  5008804      M       Y             Y         0  427500.0     Working
# 2  5008804      M       Y             Y         0  427500.0     Working
# 3  5008804      M       Y             Y         0  427500.0     Working
# 4  5008804      M       Y             Y         0  427500.0     Working
#
#           Education  Marital_Status        House_Type    Age  Experience  \
# 0  Higher education  Civil marriage  Rented apartment -12005       -4542
# 1  Higher education  Civil marriage  Rented apartment -12005       -4542
# 2  Higher education  Civil marriage  Rented apartment -12005       -4542
# 3  Higher education  Civil marriage  Rented apartment -12005       -4542
# 4  Higher education  Civil marriage  Rented apartment -12005       -4542
#
#    Mobile  Office_Phone  Phone  Email Occupation_Type  Family_Members  \
# ...

# %%
data.describe()
# Out:
#                  Id       Children        Income            Age  \
# count  7.777150e+05  777715.000000  7.777150e+05  777715.000000
# mean   5.078743e+06       0.428082  1.885348e+05  -16124.937046
# std    4.180442e+04       0.745755  1.016225e+05    4104.304018
# min    5.008804e+06       0.000000  2.700000e+04  -25152.000000
# 25%    5.044568e+06       0.000000  1.215000e+05  -19453.000000
# 50%    5.069530e+06       0.000000  1.620000e+05  -15760.000000
# 75%    5.115551e+06       1.000000  2.250000e+05  -12716.000000
# max    5.150487e+06      19.000000  1.575000e+06   -7489.000000
#
#           Experience    Mobile   Office_Phone          Phone          Email  \
# count  777715.000000  777715.0  777715.000000  777715.000000  777715.000000
# mean    57775.825016       1.0       0.231818       0.300965       0.091675
# std    136471.735391       0.0       0.421993       0.458678       0.288567
# min    -15713.000000       1.0       0.000000       0.000000       0.000000
# ...

# %%
data.isnull().sum()
# Out:
# Id                      0
# Gender                  0
# Own_Car                 0
# Property_Type           0
# Children                0
# Income                  0
# Income_Type             0
# Education               0
# Marital_Status          0
# House_Type              0
# Age                     0
# Experience              0
# Mobile                  0
# Office_Phone            0
# Phone                   0
# Email                   0
# Occupation_Type    240048
# Family_Members          0
# Month_Balance           0
# Status                  0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 777715 entries, 0 to 777714
# Data columns (total 20 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Id               777715 non-null  int64
#  1   Gender           777715 non-null  object
#  2   Own_Car          777715 non-null  object
#  3   Property_Type    777715 non-null  object
#  4   Children         777715 non-null  int64
#  5   Income           777715 non-null  float64
#  6   Income_Type      777715 non-null  object
#  7   Education        777715 non-null  object
#  8   Marital_Status   777715 non-null  object
#  9   House_Type       777715 non-null  object
#  10  Age              777715 non-null  int64
#  11  Experience       777715 non-null  int64
#  12  Mobile           777715 non-null  int64
#  13  Office_Phone     777715 non-null  int64
#  14  Phone            777715 non-null  int64
#  15  Email            777715 non-null  int64
# ...

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data['Occupation_Type'].fillna('Other',inplace=True)

# %%
data=data.dropna(subset=["Gender"])

# %%
data.shape
# Out:
# (777715, 20)

# %%
data.columns
# Out:
# Index(['Id', 'Gender', 'Own_Car', 'Property_Type', 'Children', 'Income',
#        'Income_Type', 'Education', 'Marital_Status', 'House_Type', 'Age',
#        'Experience', 'Mobile', 'Office_Phone', 'Phone', 'Email',
#        'Occupation_Type', 'Family_Members', 'Month_Balance', 'Status'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 777715 entries, 0 to 777714
# Data columns (total 20 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Id               777715 non-null  int64
#  1   Gender           777715 non-null  object
#  2   Own_Car          777715 non-null  object
#  3   Property_Type    777715 non-null  object
#  4   Children         777715 non-null  int64
#  5   Income           777715 non-null  float64
#  6   Income_Type      777715 non-null  object
#  7   Education        777715 non-null  object
#  8   Marital_Status   777715 non-null  object
#  9   House_Type       777715 non-null  object
#  10  Age              777715 non-null  int64
#  11  Experience       777715 non-null  int64
#  12  Mobile           777715 non-null  int64
#  13  Office_Phone     777715 non-null  int64
#  14  Phone            777715 non-null  int64
#  15  Email            777715 non-null  int64
# ...

# %%
data['Age'] =abs(round((data['Age']/-365),0))
data['Experience'] =abs(round((data['Experience']/-365),0))

# %%
data['Experience'].replace(1001.0, 0, inplace=True)

# %%
data.head()
# Out:
#         Id Gender Own_Car Property_Type  Children    Income Income_Type  \
# 0  5008804      M       Y             Y         0  427500.0     Working
# 1  5008804      M       Y             Y         0  427500.0     Working
# 2  5008804      M       Y             Y         0  427500.0     Working
# 3  5008804      M       Y             Y         0  427500.0     Working
# 4  5008804      M       Y             Y         0  427500.0     Working
#
#           Education  Marital_Status        House_Type   Age  Experience  \
# 0  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 1  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 2  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 3  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 4  Higher education  Civil marriage  Rented apartment  33.0        12.0
#
#    Mobile  Office_Phone  Phone  Email Occupation_Type  Family_Members  \
# ...

# %%
Gender_count = data['Gender'].value_counts()

plt.bar(Gender_count.index, Gender_count.values)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution Of Gender')
plt.show()

# %%
Car_owner_count=data['Own_Car'].value_counts()

plt.bar(Car_owner_count.index, Car_owner_count.values)
plt.xlabel('Car Owner Count')
plt.ylabel('Count')
plt.title('Distribution Of Car Owner')
plt.show()

# %%
Propety_owner_count=data['Property_Type'].value_counts()

plt.bar(Propety_owner_count.index, Propety_owner_count.values)
plt.xlabel('Property Owner Count ')
plt.ylabel('Count')
plt.title('Distribution Of Property Owner')
plt.show()

# %%
Children_count=data['Children'].value_counts()

plt.bar(Children_count.index, Children_count.values)
plt.xlabel('Children Count ')
plt.ylabel('Count')
plt.title('Distribution Of Children Count')
plt.show()

# %%
data.head(1)
# Out:
#         Id Gender Own_Car Property_Type  Children    Income Income_Type  \
# 0  5008804      M       Y             Y         0  427500.0     Working
#
#           Education  Marital_Status        House_Type   Age  Experience  \
# 0  Higher education  Civil marriage  Rented apartment  33.0        12.0
#
#    Mobile  Office_Phone  Phone  Email Occupation_Type  Family_Members  \
# 0       1             1      0      0           Other             2.0
#
#    Month_Balance Status
# 0              0      C

# %%
plt.hist(data['Income'], bins=10)
plt.xlabel('Annual Income')
plt.ylabel('Count')
plt.title('Distribution Of Annual Income')
plt.show()

# %%
Income_Type_count=data['Income_Type'].value_counts()

plt.figure(figsize=(10,7))
plt.bar(Income_Type_count.index,Income_Type_count.values)
plt.xlabel('Income Type Count ')
plt.ylabel('Count')
plt.title('Distribution Of Income Type')
plt.show()

# %%
Education_count=data['Education'].value_counts()

plt.figure(figsize=(15,7))
plt.bar(Education_count.index,Education_count.values)
plt.xlabel('Education Count ')
plt.ylabel('Count')
plt.title('Distribution Of Education Type')
plt.show()

# %%
Marital_Status_count=data['Marital_Status'].value_counts()

plt.figure(figsize=(15,7))
plt.bar(Marital_Status_count.index,Marital_Status_count.values)
plt.xlabel('Marital Status Count ')
plt.ylabel('Count')
plt.title('Distribution Of Marital Status')
plt.show()

# %%
House_Type_count=data['House_Type'].value_counts()

plt.figure(figsize=(15,7))
plt.bar(House_Type_count.index,House_Type_count.values)
plt.xlabel('House Types Count ')
plt.ylabel('Count')
plt.title('Distribution Of House Type')
plt.show()

# %%
Birthday_count=data['Age'].value_counts()

plt.figure(figsize=(15,5))
plt.bar(Birthday_count.index,Birthday_count.values)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution Of Age')
plt.show()

# %%
Experience_count=data['Experience'].value_counts()

plt.figure(figsize=(10,5))
plt.bar(Experience_count.index,Experience_count.values)
plt.xlabel('Experience')
plt.ylabel('Count')
plt.title('Distribution Of Experience')
plt.show()

# %%
Mobile_count=data['Mobile'].value_counts()

plt.figure(figsize=(10,5))
plt.bar(Mobile_count.index,Mobile_count.values)
plt.xlabel('Mobile')
plt.ylabel('Count')
plt.title('Distribution Of Mobile')
plt.show()

# %%
Office_Phone_count=data['Office_Phone'].value_counts()

plt.figure(figsize=(10,5))
plt.bar(Office_Phone_count.index,Office_Phone_count.values)
plt.xlabel('Office Phone')
plt.ylabel('Count')
plt.title('Distribution Of Office Phone')
plt.show()

# %%
Phone_count=data['Phone'].value_counts()

plt.figure(figsize=(10,5))
plt.bar(Phone_count.index,Phone_count.values)
plt.xlabel('Phone')
plt.ylabel('Count')
plt.title('Distribution Of Phone')
plt.show()

# %%
Email_count=data['Email'].value_counts()

plt.figure(figsize=(10,5))
plt.bar(Email_count.index,Email_count.values)
plt.xlabel('Email')
plt.ylabel('Count')
plt.title('Distribution Of Email')
plt.show()

# %%
Occupation_Type_count=data['Occupation_Type'].value_counts()

plt.figure(figsize=(35,15))
plt.bar(Occupation_Type_count.index,Occupation_Type_count.values)
plt.xlabel('Occupation Type')
plt.ylabel('Count')
plt.title('Distribution Of Occupation Type')
plt.show()

# %%
Family_Members_count=data['Family_Members'].value_counts()

plt.figure(figsize=(10,5))
plt.bar(Family_Members_count.index,Family_Members_count.values)
plt.xlabel('Family Members')
plt.ylabel('Count')
plt.title('Distribution Of Family Members')
plt.show()

# %%
Status_count=data['Status'].value_counts()

plt.figure(figsize=(10,5))
plt.bar(Status_count.index,Status_count.values)
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Distribution Of Status')
plt.show()

# %%
data.to_csv("Final_data.csv")

# %%
data.head(4)
# Out:
#         Id Gender Own_Car Property_Type  Children    Income Income_Type  \
# 0  5008804      M       Y             Y         0  427500.0     Working
# 1  5008804      M       Y             Y         0  427500.0     Working
# 2  5008804      M       Y             Y         0  427500.0     Working
# 3  5008804      M       Y             Y         0  427500.0     Working
#
#           Education  Marital_Status        House_Type   Age  Experience  \
# 0  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 1  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 2  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 3  Higher education  Civil marriage  Rented apartment  33.0        12.0
#
#    Mobile  Office_Phone  Phone  Email Occupation_Type  Family_Members  \
# 0       1             1      0      0           Other             2.0
# 1       1             1      0      0           Other             2.0
# ...

# %%
df =data.corr(method='spearman')

# %%
df
# Out:
#                       Id  Children    Income       Age  Experience  Mobile  \
# Id              1.000000  0.026108 -0.033408 -0.041065    0.005636     NaN
# Children        0.026108  1.000000  0.059214 -0.404064    0.127064     NaN
# Income         -0.033408  0.059214  1.000000 -0.112854    0.166938     NaN
# Age            -0.041065 -0.404064 -0.112854  1.000000   -0.197624     NaN
# Experience      0.005636  0.127064  0.166938 -0.197624    1.000000     NaN
# Mobile               NaN       NaN       NaN       NaN         NaN     NaN
# Office_Phone    0.084689  0.039495 -0.030210 -0.174725    0.152351     NaN
# Phone           0.005555 -0.023868 -0.001648  0.028112    0.027844     NaN
# Email          -0.056057  0.027936  0.082740 -0.100476    0.020215     NaN
# Family_Members  0.028286  0.829308  0.038489 -0.337182    0.138318     NaN
# Month_Balance   0.004797  0.000034 -0.001466 -0.032447   -0.031859     NaN
#
#                 Office_Phone     Phone     Email  Family_Members  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df, annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(x ='Gender',y ="Income",data=data)
plt.show()

# %%
sns.boxplot(x ='Gender',y ="Age",data=data)
plt.show()

# %%
sns.boxplot(x ='Gender',y ="Experience",data=data)
plt.show()

# %%
sns.boxplot(x ='Income',y ="Marital_Status",data=data)
plt.show()

# %%
sns.boxplot(x ='Family_Members',y ="Income",data=data)
plt.show()

# %%
sns.boxplot(x ='Income',y ="Education",data=data)
plt.show()

# %%
sns.boxplot(x ='Income',y ="Occupation_Type",data=data)
plt.show()

# %%
data.head()
# Out:
#         Id Gender Own_Car Property_Type  Children    Income Income_Type  \
# 0  5008804      M       Y             Y         0  427500.0     Working
# 1  5008804      M       Y             Y         0  427500.0     Working
# 2  5008804      M       Y             Y         0  427500.0     Working
# 3  5008804      M       Y             Y         0  427500.0     Working
# 4  5008804      M       Y             Y         0  427500.0     Working
#
#           Education  Marital_Status        House_Type   Age  Experience  \
# 0  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 1  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 2  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 3  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 4  Higher education  Civil marriage  Rented apartment  33.0        12.0
#
#    Mobile  Office_Phone  Phone  Email Occupation_Type  Family_Members  \
# ...

# %%
dfx =data.drop(['Id','Office_Phone','Mobile','Email','Phone'], axis=1)

# %%
dfx.head()
# Out:
#   Gender Own_Car Property_Type  Children    Income Income_Type  \
# 0      M       Y             Y         0  427500.0     Working
# 1      M       Y             Y         0  427500.0     Working
# 2      M       Y             Y         0  427500.0     Working
# 3      M       Y             Y         0  427500.0     Working
# 4      M       Y             Y         0  427500.0     Working
#
#           Education  Marital_Status        House_Type   Age  Experience  \
# 0  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 1  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 2  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 3  Higher education  Civil marriage  Rented apartment  33.0        12.0
# 4  Higher education  Civil marriage  Rented apartment  33.0        12.0
#
#   Occupation_Type  Family_Members  Month_Balance Status
# 0           Other             2.0              0      C
# ...

# %%
# Train and  Test dat

# %%
# importing Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in dfx:
    if dfx[col].dtype =='object':
       dfx[col] = le.fit_transform(dfx[col])

# %%
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 777715 entries, 0 to 777714
# Data columns (total 15 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Gender           777715 non-null  int32
#  1   Own_Car          777715 non-null  int32
#  2   Property_Type    777715 non-null  int32
#  3   Children         777715 non-null  int64
#  4   Income           777715 non-null  float64
#  5   Income_Type      777715 non-null  int32
#  6   Education        777715 non-null  int32
#  7   Marital_Status   777715 non-null  int32
#  8   House_Type       777715 non-null  int32
#  9   Age              777715 non-null  float64
#  10  Experience       777715 non-null  float64
#  11  Occupation_Type  777715 non-null  int32
#  12  Family_Members   777715 non-null  float64
#  13  Month_Balance    777715 non-null  int64
#  14  Status           777715 non-null  int32
# dtypes: float64(4), int32(9), int64(2)
# memory usage: 68.2 MB

# %%
dfx.shape
# Out:
# (777715, 15)

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split

X =dfx.iloc[:,0:-1]
y =dfx.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size =0.4,random_state=60)

# %%
X_test.shape
# Out:
# (311086, 14)

# %%
X_train.shape
# Out:
# (466629, 14)

# %%
y_test.shape
# Out:
# (311086,)

# %%
y_train.shape
# Out:
# (466629,)

# %% [markdown]
# # Scaling

# %%
#importing the MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler(feature_range=(0,1))
rescale_X_train = scaler.fit_transform(X_train)
rescale_X_test = scaler.fit_transform(X_test)
print(rescale_X_train.shape)
print(rescale_X_test.shape)
# Out:
# (466629, 14)
# (311086, 14)

# %% [markdown]
# **Applying ML algorithm to the pre-processed columns and find out, which of these algorithms is best suitable.

# %% [markdown]
# # 1.Logistic Regression

# %%
# importing the LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

logreg=LogisticRegression(random_state=0)
logreg.fit(rescale_X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
#Importing scikit-learn metrics module for accuracy calculation

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix, accuracy_score

y_pred = logreg.predict(rescale_X_test)
print("Logistic Regression Training Set:",logreg.score(X_train, y_train))
print("Logistic Regression Testing Set:",logreg.score(X_test, y_test))
print("Accuracy Of Logistic Regression Classifier: ", accuracy_score(y_test,y_pred))

print(confusion_matrix(y_test,y_pred))
# Out:
# Logistic Regression Training Set: 0.37467881336136416
# Logistic Regression Testing Set: 0.3723021929627177
# Accuracy Of Logistic Regression Classifier:  0.4692368026847881
# [[50647     0     0     0     0     0 65171     0]
#  [ 1477     0     0     0     0     0  2030     0]
#  [  139     0     0     0     0     0   168     0]
#  [   57     0     0     0     0     0    59     0]
#  [   45     0     0     0     0     0    59     0]
#  [  217     0     0     0     0     0   409     0]
#  [36701     0     0     0     0     0 95326     0]
#  [22778     0     0     0     0     0 35803     0]]

# %% [markdown]
# # Cross validation

# %%
from sklearn.model_selection import ShuffleSplit

model= LogisticRegression()
ssplit=ShuffleSplit(n_splits=20,test_size=0.50)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,X,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.46508494 0.46815547 0.46715253 0.46758971 0.46638362 0.46729912
#  0.46939243 0.46511323 0.46770543 0.42374851 0.43813166 0.46838692
#  0.46834577 0.46829691 0.46824548 0.46956987 0.46897582 0.46879066
#  0.46921755 0.4670651 ]
# 0.4641325368129238

# %% [markdown]
# # 2.Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

classification = DecisionTreeClassifier()
classification = classification.fit(X_train,y_train)
y_pred = classification.predict(X_test)
print("Decision Tree Training Set:",classification.score(X_train, y_train))
print("Decision Tree Testing Set:",classification.score(X_test, y_test))
print("Accuracy:", accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# Decision Tree Training Set: 0.79723720557445
# Decision Tree Testing Set: 0.5817330255942087
# Accuracy: 0.5817330255942087
# [[72692  1428   100    29    22   105 29701 11741]
#  [ 1777   477    45     7     1    11   868   321]
#  [  102    52    30    12     4     6    79    22]
#  [   36     4    25     6     8     6    23     8]
#  [   23     2     8    20     5    10    29     7]
#  [  150    11     3     6    21   267   126    42]
#  [38909   905    75    35    26   110 83314  8653]
#  [19151   407    33    13     4    41 14754 24178]]

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import ShuffleSplit

model= DecisionTreeClassifier()
ssplit=ShuffleSplit(n_splits=20,test_size=0.50)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,X,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.57977719 0.57715927 0.57925001 0.58184479 0.57985691 0.5782445
#  0.5790057  0.57462621 0.57899027 0.57865853 0.57719785 0.57953032
#  0.57843994 0.57576545 0.57578602 0.57925001 0.57776875 0.58013979
#  0.57525369 0.57814935]
# 0.5782347283584239

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

rf = RandomForestClassifier()
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
print("Random Forest Taining Set:",rf.score(X_train, y_train))
print("Random Forest Testing Set:",rf.score(X_test, y_test))
print("Random Forest Classifier Accuracy: ", rf.score(X_test, y_test))
# Evaluate the confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# Random Forest Taining Set: 0.7972329195142179
# Random Forest Testing Set: 0.6089055759500588
# Random Forest Classifier Accuracy:  0.6089055759500588
# [[69007  1069    67    25    18    92 31905 13635]
#  [ 1653   499    31     4     0    11   954   355]
#  [   95    57    25    12     3     4    82    29]
#  [   26     4    29     4     6     6    30    11]
#  [   16     2     7    27     5     8    33     6]
#  [  117    11     0     4    24   261   159    50]
#  [28705   615    45    24    12    99 91291 11236]
#  [15470   272    26     7     0    37 14439 28330]]

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import ShuffleSplit

model=RandomForestClassifier()
ssplit=ShuffleSplit(n_splits=20,test_size=0.50)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,X,y,cv=ssplit)
print(results)
print(np.mean(results))

# %%
Hence we got accuracy on different classification

-logisitic regression got accuracy 46%

-DecisionTree got accuracy 58%

-Random Forest got accuracy 60%

we have done all the elementry EDA steps

After feature selection we used four machine learning models and achieved quite good accuracy 60% in Random Forest for predicting the credit card approval.
